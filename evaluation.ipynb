# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import sklearn.metrics.pairwise as pw

from data import BUSINESSES, CITIES, REVIEWS, USERS, get_business

def topbusinesses():
    poep = list()
    plas = list()
    kots = list()
    for city in CITIES:
        print(city)
        for business in BUSINESSES[city]:
            if 'Restaurants' in business['categories']:
                poep.append(business['business_id'])
                plas.append(business['review_count'])
                kots.append(business['stars'])
    df_ratings = pd.DataFrame(columns=['business_id', 'review_count','rating'])
    df_ratings['business_id'] = poep
    df_ratings['review_count'] = plas
    df_ratings['rating'] = kots
    df_ratings = df_ratings.sort_values(by='review_count', ascending=False).iloc[0:10]
    return df_ratings

# topbusinesses()

def Idontevenknowwhatimdoinganymore():
    nee = list()
    haha = list()
    for city in CITIES:
#         print(city)
        if city == 'westlake':
            for review in REVIEWS[city]:
                if review['business_id'] == 'ZTg8adZipR3QDoJmFZZqJw':
                    haha.append(review['user_id'])
    return haha
# print(Idontevenknowwhatimdoinganymore())
            
def dfmaker():
    businesslist = list()
    categorieslist = list()
    starlist = list()
    useridlist = list()
    review_count = list()
    poep = list()
    for city in CITIES:
        for review in REVIEWS[city]:
            useridlist.append(review['user_id'])
            starlist.append(review['stars'])
            businesslist.append(review['business_id'])
            for city in CITIES:
                for business in BUSINESSES[city]:
                    review_count.append(business['review_count'])
                    poep.append(business['business_id'])
                    if business['business_id'] == review['business_id']:
                        data = json.loads(json.dumps(business))
                        categories = data["categories"]
                        categorieslist.append(categories)
                       
    df_ratings = pd.DataFrame(columns=['user_id', 'business_id', 'rating', 'categories', 'review_count'])
    df_ratings['user_id'] = useridlist
    df_ratings['business_id'] = businesslist
    df_ratings['categories'] = categorieslist
    df_ratings['rating'] = starlist 
    df_ratings['review_count'] = review_count
    df_ratings = df_ratings.sort_values(by='review_count')
    # df_ratings = df_ratings.groupby('user_id')
    # print(df_ratings)
    return df_ratings


def dfmakercategories():
    businesslist = list()
    categorieslist = list()

    for city in CITIES:
        for i in BUSINESSES[city]:
            data = json.loads(json.dumps(i))
            categories = data["categories"]
            for j in list(categories.split(",")):
                    newj = j.replace(" ", "")
                    businesslist.append(data['business_id'])
                    categorieslist.append(newj)

    series_ratings = pd.DataFrame(columns=['business_id', 'categories'])
    series_ratings['business_id'] = businesslist
    series_ratings['categories'] = categorieslist
    return series_ratings


def dfmakerratings():
    businesslist = list()
    categorieslist = list()
    starlist = list()
    useridlist = list()
    for city in CITIES:
        for review in REVIEWS[city]:
            useridlist.append(review['user_id'])
            starlist.append(review['stars'])
            businesslist.append(review['business_id'])
            # for city in CITIES:
            #     for business in BUSINESSES[city]:
            #         if business['business_id'] == review['business_id']:
            #             data = json.loads(json.dumps(business))
            #             categories = data["categories"]
            #             categorieslist.append(categories)
                    
    df_ratings = pd.DataFrame(columns=['user_id', 'business_id', 'rating'])
    df_ratings['user_id'] = useridlist
    df_ratings['business_id'] = businesslist
    df_ratings['rating'] = starlist 
    # df_ratings = df_ratings.sort_values(by='user_id')
    # df_ratings = df_ratings.drop_duplicates()
    # print(df_ratings)
    return df_ratings

def pivot_genres(df):
    """Create a one-hot encoded matrix for genres.
    
    Output:
    a matrix containing '0' or '1' in each cell.
    1: the movie has the genre
    0: the movie does not have the genre
    """
    return df.pivot_table(index = 'business_id', columns = 'categories', aggfunc = 'size', fill_value=0)

def pivot_ratings(df):
    """Creates a utility matrix for user ratings for movies
    
    Arguments:
    df -- a dataFrame containing at least the columns 'movieId' and 'genres'
    
    Output:
    a matrix containing a rating in each cell. np.nan means that the user did not rate the movie
    """
    return df.pivot_table(values='rating', columns='user_id', index='business_id')

def create_similarity_matrix_categories(matrix):
    """Create a  """
    npu = matrix.values
    m1 = npu @ npu.T
    diag = np.diag(m1)
    m2 = m1 / diag
    m3 = np.minimum(m2, m2.T)
    # print(pd.DataFrame(m3, index = matrix.index, columns = matrix.index))
    return pd.DataFrame(m3, index = matrix.index, columns = matrix.index)

def predict_ratings(similarity, utility, to_predict):
    """Predicts the predicted rating for the input test data.
    
    Arguments:
    similarity -- a dataFrame that describes the similarity between items
    utility    -- a dataFrame that contains a rating for each user (columns) and each movie (rows). 
                  If a user did not rate an item the value np.nan is assumed. 
    to_predict -- A dataFrame containing at least the columns movieId and userId for which to do the predictions
    """
    # copy input (don't overwrite)
    ratings_test_c = to_predict.copy()
    # apply prediction to each row
    ratings_test_c['predicted rating'] = to_predict.apply(lambda row: predict_ids(similarity, utility, row['user_id'], row['business_id']), axis=1)
    # print(ratings_test_c)
    return ratings_test_c

### Helper functions for predict_ratings_item_based ###

def predict_ids(similarity, utility, userId, itemId):
    # select right series from matrices and compute
    if userId in utility.columns and itemId in similarity.index:
        return predict_vectors(utility.loc[:,userId], similarity[itemId])
    
    return 0

def predict_vectors(user_ratings, similarities):
    # select only movies actually rated by user
    relevant_ratings = user_ratings.dropna()
    
    # select corresponding similairties
    similarities_s = similarities[relevant_ratings.index]
    
    # select neighborhood
    similarities_s = similarities_s[similarities_s > 0.0]
    relevant_ratings = relevant_ratings[similarities_s.index]
    
    # if there's nothing left return a prediction of 0
    norm = similarities_s.sum()
    if(norm == 0):
        return 0
    
    # compute a weighted average (i.e. neighborhood is all) 
    return np.dot(relevant_ratings, similarities_s)/norm

def mse(predicted_ratings):
    """Computes the mean square error between actual ratings and predicted ratings
    
    Arguments:
    predicted_ratings -- a dataFrame containing the columns rating and predicted rating
    """
    diff = predicted_ratings['rating'] - predicted_ratings['predicted rating']
    # print("MSE:", diff**2)
    return (diff**2).mean()

def split_data(data, d = 0.75):
    """Split data in a training and test set.
    
    Arguments:
    data -- any dataFrame.
    d    -- the fraction of data in the training set
    """
    np.random.seed(seed=5)
    mask_test = np.random.rand(data.shape[0]) < d
    return data[mask_test], data[~mask_test]

def dfmakersuited(city, user_id):
    businesslist = list()
    categorieslist = list()
    starlist = list()
    useridlist = list()
    
    for review in REVIEWS[city]:
        if review['user_id'] == user_id:
            useridlist.append(review['user_id'])
            starlist.append(review['stars'])
            businesslist.append(review['business_id'])

        
    for business in BUSINESSES[city]:
        if business['business_id'] not in businesslist:
            businesslist.append(business['business_id'])
            starlist.append(np.nan)
            useridlist.append(user_id)
                    
    df_ratings = pd.DataFrame(columns=['user_id', 'business_id', 'rating'])
    df_ratings['user_id'] = useridlist
    df_ratings['business_id'] = businesslist
    df_ratings['rating'] = starlist 
    # df_ratings = df_ratings.sort_values(by='user_id')
    # df_ratings = df_ratings.groupby('user_id')
    # print(df_ratings)
    return df_ratings

soep = Idontevenknowwhatimdoinganymore()
SElist = list()
for i in soep:
    # new test
    dfratings = dfmakersuited("westlake", i) 
    dfutility = pivot_genres(dfmakercategories())
    dfsimilarity = create_similarity_matrix_categories(dfutility)
    dfutilityratings = pivot_ratings(dfratings)
    predicted_genres = predict_ratings(dfsimilarity, dfutilityratings, dfratings[['user_id', 'business_id', 'rating']])
    ugh = predicted_genres[predicted_genres['business_id']=='ZTg8adZipR3QDoJmFZZqJw']
#     print(type(ugh))
    print(ugh)
    for i,j in zip(ugh['rating'],ugh['predicted rating']):
        SElist.append((i-j)**2)
#         SElist.append(float((i['rating']-i['predicted rating'])**2))
#         print(float((i['rating']-i['predicted rating'])**2))
#         print((predicted_genres['rating']-predicted_genres['predicted rating'])**2)
#     print(float((ugh['rating']-ugh['predicted rating'])**2))
# Out:
#                   user_id             business_id  rating  predicted rating
# 2  REdMk8qjYKdCt2AJ_UQ2ow  ZTg8adZipR3QDoJmFZZqJw     5.0          4.833333
#                    user_id             business_id  rating  predicted rating
# 13  4mTp-ba1gdgxrNfD_7RIQg  ZTg8adZipR3QDoJmFZZqJw     4.0          3.184837
#                   user_id             business_id  rating  predicted rating
# 0  od3xciIA-n22_FqeZvkZEQ  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 0  OSpCfR5-k3vgOTX_VDOQmw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 3  OaXJlsA-qymC9fAkhwrcEw  ZTg8adZipR3QDoJmFZZqJw     4.0          4.285714
#                   user_id             business_id  rating  predicted rating
# 0  fOrLeUUStbSGMYj_n6oXnw  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  Z_A79O8vUZ3nI6Uzx3w6vA  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 0  ql0DMsBGTlVwsZjxE8mJ-A  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  ErpgWdzghVjBgXQLX8iW1w  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 0  xvk00Z6KlNVyPytQjvWRvA  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  bBXZv39ymYs3Q9TJKcmsmA  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 1  iDLeL3fXEBqd9wUS9Imn4g  ZTg8adZipR3QDoJmFZZqJw     5.0          3.698795
#                   user_id             business_id  rating  predicted rating
# 1  bC-InVsdpTl6OQusU2mD1g  ZTg8adZipR3QDoJmFZZqJw     5.0          4.785714
#                   user_id             business_id  rating  predicted rating
# 1  iQCfS60OW_OBA7NrbAkboQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  64lb3N95RmOtcX0rUk1bnw  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 0  g8l9xP5WDnPYu0N-zfsepg  ZTg8adZipR3QDoJmFZZqJw     3.0               3.0
#                   user_id             business_id  rating  predicted rating
# 2  nOr3_aq60yivqgcso_iDMw  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  wh7_Oxsi1bdWDxYpRnEL_Q  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 7  lEw2VL9JCDFk3R5NzahqnA  ZTg8adZipR3QDoJmFZZqJw     4.0          3.350723
#                   user_id             business_id  rating  predicted rating
# 0  ELXXHQgnh_VyWNd3_-dPjQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 1  IchBvxqHHoCujy9mfVSMmg  ZTg8adZipR3QDoJmFZZqJw     5.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  22-tmsxbgihz7Lgwz-mlPw  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                    user_id             business_id  rating  predicted rating
# 14  XhtMmcvMN4h9NF4C-eGD0g  ZTg8adZipR3QDoJmFZZqJw     5.0          4.085714
#                   user_id             business_id  rating  predicted rating
# 0  kOt2GBluRDcDoZ9vxuUh5g  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 4  wISdr15RJTBtlhilcayCpA  ZTg8adZipR3QDoJmFZZqJw     5.0          4.217391
#                   user_id             business_id  rating  predicted rating
# 0  3XHugNNeIf0bU_Ho_zBCfA  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  8KeHUYvc5HVzex6XhP6Fug  ZTg8adZipR3QDoJmFZZqJw     3.0          3.228571
# 1  8KeHUYvc5HVzex6XhP6Fug  ZTg8adZipR3QDoJmFZZqJw     2.0          3.228571
# 2  8KeHUYvc5HVzex6XhP6Fug  ZTg8adZipR3QDoJmFZZqJw     5.0          3.228571
#                   user_id             business_id  rating  predicted rating
# 0  kXKCJcfhNpAQTNoeT3fqdQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  h5EHAj4CKcxaHFPExSDP6w  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 2  5OsTNHbOiphXtcelSISP1w  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 1  1ZjHE1Q5hytV48M1nFHBjQ  ZTg8adZipR3QDoJmFZZqJw     3.0          2.272727
#                    user_id             business_id  rating  predicted rating
# 9   5RLOLqj8f0MMJ5OJVXTeYQ  ZTg8adZipR3QDoJmFZZqJw     4.0          2.653659
# 10  5RLOLqj8f0MMJ5OJVXTeYQ  ZTg8adZipR3QDoJmFZZqJw     1.0          2.653659
#                   user_id             business_id  rating  predicted rating
# 2  X3Nw8fvoRh-LLyJcWBfMow  ZTg8adZipR3QDoJmFZZqJw     3.0          3.545455
#                   user_id             business_id  rating  predicted rating
# 0  MBiYvAWq0o-MIOzDs7UHvA  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  FWQ_Vwkq-XjMq1E2LbiZkw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 2  hGFtUnm7mNttUJ867YD_hA  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 0  Emjc5OhqDP5ORkIuxsAzQA  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 1  N3COlIajBlXtDLC7zLPFyg  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  yBa0u6l1pNMb1Pigw09RDQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  Iw5O8qETvc-cv1pDpCMLAg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  KiK8ShJ1KDZ2gM1o6Fon9A  ZTg8adZipR3QDoJmFZZqJw     1.0          2.333333
#                   user_id             business_id  rating  predicted rating
# 0  eAxUkcx72pncwSLb6XkQUg  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  ZSZ2nMsJF1OVJbJ1NP2Kpw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 2  wDS2IgK5uTgx-NXum8jPBw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.923077
#                   user_id             business_id  rating  predicted rating
# 4  IZHPwalZ6PPqsgJZRa732Q  ZTg8adZipR3QDoJmFZZqJw     3.0          3.491525
#                   user_id             business_id  rating  predicted rating
# 1  AH3OZj4glpss6xXpOEHF7Q  ZTg8adZipR3QDoJmFZZqJw     4.0          3.846154
#                   user_id             business_id  rating  predicted rating
# 0  39TXRgvloQS-oObFEadV3g  ZTg8adZipR3QDoJmFZZqJw     3.0               3.0
#                    user_id             business_id  rating  predicted rating
# 28  lJFBgSAccsMGwIjfD7LMeQ  ZTg8adZipR3QDoJmFZZqJw     5.0          3.741384
#                   user_id             business_id  rating  predicted rating
# 0  T9tEic49JZjN4nCUcDvrRQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 1  O9Pd0jinLW4nIv3VWlESGQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  En0tIC_BCSZ2sUaepHpttg  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 1  Fmq0K0QZNJ9_m7NcV0TqbQ  ZTg8adZipR3QDoJmFZZqJw     5.0          4.333333
#                   user_id             business_id  rating  predicted rating
# 0  IoGdMC0ZqjdGSUDH7Py6tg  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 2  OT2pxRA_3oNLv_c2l2mbGw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 1  J4ai0ltVgepBN3alp6LerA  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  skKBb80NOne4ApSfihdQ-A  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 5  AXBsPgSbyjGkAqPLSwiTYg  ZTg8adZipR3QDoJmFZZqJw     4.0          3.907285
#                   user_id             business_id  rating  predicted rating
# 3  cIcB-hi3zOVYXk7vsWrxQw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.482353
#                   user_id             business_id  rating  predicted rating
# 0  bbfwZ-2Pf6hLgEBUNRNsvA  ZTg8adZipR3QDoJmFZZqJw     3.0          3.166667
#                   user_id             business_id  rating  predicted rating
# 1  jCWtXIlGt4ZzbHPXfIXceA  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  l84qXo00dMsnTfW_d-wcGQ  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 2  DIqmYwkcPFcYnEpWvzXeOQ  ZTg8adZipR3QDoJmFZZqJw     5.0          4.833333
#                   user_id             business_id  rating  predicted rating
# 2  vipsbsgNyZOiLG5321DGiA  ZTg8adZipR3QDoJmFZZqJw     5.0          4.833333
#                   user_id             business_id  rating  predicted rating
# 0  zOYVn8fzLMEwGCpyyGYWdA  ZTg8adZipR3QDoJmFZZqJw     3.0               3.0
#                   user_id             business_id  rating  predicted rating
# 7  wEkJLnEHpJiUuYL6mNmElw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.429319
#                   user_id             business_id  rating  predicted rating
# 0  Q98eIfdE2EWWcszF9_ObUQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  oHS5-x4aWMR-MMTi_QYDww  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  edOdAuUX6-yaqikrJkmiqg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                    user_id             business_id  rating  predicted rating
# 9   5RLOLqj8f0MMJ5OJVXTeYQ  ZTg8adZipR3QDoJmFZZqJw     4.0          2.653659
# 10  5RLOLqj8f0MMJ5OJVXTeYQ  ZTg8adZipR3QDoJmFZZqJw     1.0          2.653659
#                   user_id             business_id  rating  predicted rating
# 0  8KeHUYvc5HVzex6XhP6Fug  ZTg8adZipR3QDoJmFZZqJw     3.0          3.228571
# 1  8KeHUYvc5HVzex6XhP6Fug  ZTg8adZipR3QDoJmFZZqJw     2.0          3.228571
# 2  8KeHUYvc5HVzex6XhP6Fug  ZTg8adZipR3QDoJmFZZqJw     5.0          3.228571
#                   user_id             business_id  rating  predicted rating
# 1  WJT2UaFRIPk-TCCm2PcDmQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  BiXSBsO-QwOQSpbuGaX-Zw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  8ccH8A61wWSSPWMnR-s2ZA  ZTg8adZipR3QDoJmFZZqJw     5.0          4.555556
#                   user_id             business_id  rating  predicted rating
# 3  eBnedff2L15dAxfD_btx-Q  ZTg8adZipR3QDoJmFZZqJw     4.0          3.584158
#                   user_id             business_id  rating  predicted rating
# 1  w9g095nfQpjTFaRq_-tfHw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.777778
#                   user_id             business_id  rating  predicted rating
# 5  DfzNhxWVPp8iZm_laj50Zw  ZTg8adZipR3QDoJmFZZqJw     5.0          4.356998
#                   user_id             business_id  rating  predicted rating
# 0  MoNnKSfnheBPArzhtGhQrA  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 0  BF1VQec8LxZdg4Lk_-0JFQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 1  _kP32LOsS2Tp4E0jK4hDYQ  ZTg8adZipR3QDoJmFZZqJw     2.0          1.833333
#                   user_id             business_id  rating  predicted rating
# 1  mLA2GSXEHgOtBROkbPVDlw  ZTg8adZipR3QDoJmFZZqJw     5.0               4.8
#                   user_id             business_id  rating  predicted rating
# 3  _HbMOgD3fXGDkUs0ZPyVzQ  ZTg8adZipR3QDoJmFZZqJw     5.0           4.79405
# 4  _HbMOgD3fXGDkUs0ZPyVzQ  ZTg8adZipR3QDoJmFZZqJw     5.0           4.79405
#                   user_id             business_id  rating  predicted rating
# 0  O2ASSka7du50Rl1vxmpNBA  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  zTB-KhTx3J7pQyhC6kdpwQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 2  OH93UQIpOSHdYH86UEflhw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
# 4  OH93UQIpOSHdYH86UEflhw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  1N3LYjdup3h3djYqI-ludQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  HdfvCa50HpjeKgK-0YMYXQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 1  NzxyUjt4nmib3wwgvhI2Hg  ZTg8adZipR3QDoJmFZZqJw     3.0          3.333333
#                   user_id             business_id  rating  predicted rating
# 5  QghVrWnEWPO7rtWfr0gviQ  ZTg8adZipR3QDoJmFZZqJw     5.0          4.724138
#                   user_id             business_id  rating  predicted rating
# 2  bB4yzmVlnk3fqhE9ZhiLTQ  ZTg8adZipR3QDoJmFZZqJw     4.0          3.888889
#                   user_id             business_id  rating  predicted rating
# 0  wk2WEDfI2XI499MPLYHu5Q  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  anz1kujkPmK_FpNXaHCRrg  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 0  d9041B1WibAZcHw9EdPJ-g  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  ol41034oA4J6R-IpokhxIw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  X04cq2XS5iy6nHIAY3UI1A  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 4  8U9bQ6ctbM6HCB9hqTCUTw  ZTg8adZipR3QDoJmFZZqJw     3.0          3.888889
# 5  8U9bQ6ctbM6HCB9hqTCUTw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.888889
# 6  8U9bQ6ctbM6HCB9hqTCUTw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.888889
#                   user_id             business_id  rating  predicted rating
# 0  hgHt7EFXkFifsN9YrScvPQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 1  tj96TR4HL5HgnXRupBBMxQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  AONEXWxzA6uSDrAhcKpXCg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                    user_id             business_id  rating  predicted rating
# 14  owj_Ij0UvMi8ZiGa_Y_deg  ZTg8adZipR3QDoJmFZZqJw     3.0           3.54067
#                   user_id             business_id  rating  predicted rating
# 0  SGkmjgjMcTW7c4GrAW5MRw  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 6  q9wybk4CFfoRI5BLL2gS7g  ZTg8adZipR3QDoJmFZZqJw     5.0           4.39267
#                   user_id             business_id  rating  predicted rating
# 6  mGGB_SCShKgmkx959MFXUw  ZTg8adZipR3QDoJmFZZqJw     5.0          4.076923
# 7  mGGB_SCShKgmkx959MFXUw  ZTg8adZipR3QDoJmFZZqJw     3.0          4.076923
# 8  mGGB_SCShKgmkx959MFXUw  ZTg8adZipR3QDoJmFZZqJw     5.0          4.076923
#                   user_id             business_id  rating  predicted rating
# 0  xNRp0U21Amk2ZwWQpPJpEQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  bGO7SyiKDmgsvSQhbtTbtg  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 4  etTn2JUCfWBuWmT7GzLm8g  ZTg8adZipR3QDoJmFZZqJw     4.0          4.058824
#                   user_id             business_id  rating  predicted rating
# 0  oop1ieL2cW6Oe6D7PlKaUA  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  jtzdo1MPyzY52lVtmnHU4A  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  sAguDf_GGRqoILqnAAaiKg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 1  nfcBvVbzRqVU_qoq423gtg  ZTg8adZipR3QDoJmFZZqJw     3.0               2.5
#                   user_id             business_id  rating  predicted rating
# 0  9WvuooWIiDaLJyjozxGI6w  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  CmXhDRVMt_0BkvQ43foE4g  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  G6Ra8WFXpAMze_xatASjcg  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 1  7UrEYOBQ34ev0KFVInnDtA  ZTg8adZipR3QDoJmFZZqJw     3.0               3.0
#                   user_id             business_id  rating  predicted rating
# 0  xnhwJEuHU_aSvINBcoCCgw  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                    user_id             business_id  rating  predicted rating
# 15  EFYa6Whx_Q01J9fYvfUXvA  ZTg8adZipR3QDoJmFZZqJw     5.0          3.500993
#                   user_id             business_id  rating  predicted rating
# 2  vts4NeIL3G4jZW3xD_Kdiw  ZTg8adZipR3QDoJmFZZqJw     5.0          4.916667
#                   user_id             business_id  rating  predicted rating
# 0  RqhuwjD6r9kHHCm8xWTg5g  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  gucwlxaow3pRYNEy6I3tFg  ZTg8adZipR3QDoJmFZZqJw     3.0               3.0
#                   user_id             business_id  rating  predicted rating
# 0  gRoufj2IWV3XMJFinZYaQg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  83cecJaBXy679ONpG7qFhg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                    user_id             business_id  rating  predicted rating
# 11  El4Hgp615lAyGOTkjKfBoQ  ZTg8adZipR3QDoJmFZZqJw     4.0          3.983565
#                   user_id             business_id  rating  predicted rating
# 0  RF8asLXwkM4v1HWZ2rya6Q  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  TSEkIphIYOC9ebUVggdDxg  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 1  k4fFb1LrxMidbYrmVsgNhg  ZTg8adZipR3QDoJmFZZqJw     3.0               2.8
#                   user_id             business_id  rating  predicted rating
# 1  2hDfmEzwbUL6j5W3jg-HuQ  ZTg8adZipR3QDoJmFZZqJw     4.0               4.0
#                   user_id             business_id  rating  predicted rating
# 0  O5U882sx9llECoa1yn35Nw  ZTg8adZipR3QDoJmFZZqJw     1.0          1.666667
#                   user_id             business_id  rating  predicted rating
# 4  oAil_gYOXUhqWnKA8SwKsw  ZTg8adZipR3QDoJmFZZqJw     4.0          3.666667
#                   user_id             business_id  rating  predicted rating
# 0  MGweyfKdWfONr8OKebW0jQ  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 7  6BtVeOYc7Sagm8-sPcsNdg  ZTg8adZipR3QDoJmFZZqJw     5.0               3.6
# 8  6BtVeOYc7Sagm8-sPcsNdg  ZTg8adZipR3QDoJmFZZqJw     3.0               3.6
#                   user_id             business_id  rating  predicted rating
# 3  LIBCmKxseYYK4w7GOvRqsw  ZTg8adZipR3QDoJmFZZqJw     5.0          4.344086
#                    user_id             business_id  rating  predicted rating
# 12  e3fdrK1tMCwWLr76LFe-cA  ZTg8adZipR3QDoJmFZZqJw     4.0          3.101804
#                   user_id             business_id  rating  predicted rating
# 0  PF2VdwHv1KMfhiO7rCJ2Og  ZTg8adZipR3QDoJmFZZqJw     5.0               5.0
#                   user_id             business_id  rating  predicted rating
# 0  Fu4nvqsFVVZLCPhJZSIa1A  ZTg8adZipR3QDoJmFZZqJw     2.0               2.0
#                   user_id             business_id  rating  predicted rating
# 1  WynWrezIjqtRVP_7APQhCg  ZTg8adZipR3QDoJmFZZqJw     5.0          3.222222
#                   user_id             business_id  rating  predicted rating
# 0  di1HA5nvR45r9Y9tBFlGyQ  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 2  6VHidrtljUzTYy4KEZyKTg  ZTg8adZipR3QDoJmFZZqJw     4.0          4.183673
#                   user_id             business_id  rating  predicted rating
# 1  huPBB0ySc26ERCncgqvYOQ  ZTg8adZipR3QDoJmFZZqJw     1.0               1.0
#                   user_id             business_id  rating  predicted rating
# 0  VULFcmvS5-zp1wt-aokPwA  ZTg8adZipR3QDoJmFZZqJw     3.0               3.0
#                   user_id             business_id  rating  predicted rating
# 1  VRuWlPtkk4iKEbX9xOZIbQ  ZTg8adZipR3QDoJmFZZqJw     3.0          3.166667

# %%
meanSE = sum(SElist)/len(SElist)
print(meanSE)
# Out:
# 0.24196461464915375
